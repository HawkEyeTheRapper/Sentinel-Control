# %% [markdown]
# # First Light
#
# **Series:** The Unveiling (02_The_Unveiling)  \
# **Book ID:** `01_First_Light`  \
# **Sequence:** 1

# %% [markdown]
# ### Tags
# `Kalina arc`, `Warlord seed`, `dragon omen`, `SunSpeaker prophecy`, `Zahara’s dream`, `origin of the lattice`

# %% [markdown]
# ### Primary Characters
# Kalina, Halana, Zahara Marshall

# %% [markdown]
# ### Lineage Thread
# - Halana — Last Sunspeaker (Light)

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Valor** → [01_VALOR/01_When_First_They_Came](../../01_VALOR/01_When_First_They_Came/Master.ipynb)
# - **Nightfall** → [03_Nightfall/01_The_Beginning](../../03_Nightfall/01_The_Beginning/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
