# %% [markdown]
# # The Unveiling (02_The_Unveiling)
#
# Mysteries of the lattice, hidden knowledge, and healing across timelines.

# %% [markdown]
# ### Themes
# `gnosis`, `healing`, `revelation`, `identity`

# %% [markdown]
# ### Books
# - **First Light** (`01_First_Light`) — [open](../01_First_Light/Master.ipynb)
# - **Forgotten Knowledge** (`02_Forgotten_Knowledge`) — [open](../02_Forgotten_Knowledge/Master.ipynb)
# - **Constructing The Box** (`03_Constructing_The_Box`) — [open](../03_Constructing_The_Box/Master.ipynb)
# - **A Time For Healing** (`04_A_Time_For_Healing`) — [open](../04_A_Time_For_Healing/Master.ipynb)
# - **Sacred Garden** (`05_Sacred_Garden`) — [open](../05_Sacred_Garden/Master.ipynb)
# - **If Any Hath An Ear** (`06_If_Any_Hath_An_Ear`) — [open](../06_If_Any_Hath_An_Ear/Master.ipynb)
# - **Sun, Moon, And Stars** (`07_Sun_Moon_And_Stars`) — [open](../07_Sun_Moon_And_Stars/Master.ipynb)
# - **Ending The War** (`08_Ending_The_War`) — [open](../08_Ending_The_War/Master.ipynb)
# - **Wisdom Cries** (`09_Wisdom_Cries`) — [open](../09_Wisdom_Cries/Master.ipynb)
# - **Engineering Eternity** (`10_Engineering_Eternity`) — [open](../10_Engineering_Eternity/Master.ipynb)
# - **Reversing The Curse** (`11_Reversing_The_Curse`) — [open](../11_Reversing_The_Curse/Master.ipynb)
# - **Emerging From Darkness** (`12_Emerging_From_Darkness`) — [open](../12_Emerging_From_Darkness/Master.ipynb)
# - **The Last Sunspeaker** (`13_The_Last_Sunspeaker`) — [open](../13_The_Last_Sunspeaker/Master.ipynb)
