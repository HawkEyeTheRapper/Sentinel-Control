# %% [markdown]
# # A Time For Healing
#
# **Series:** The Unveiling (02_The_Unveiling)  \
# **Book ID:** `04_A_Time_For_Healing`  \
# **Sequence:** 4

# %% [markdown]
# ### Tags
# `Avendar arc`, `Physician archetype seed`, `healing the lattice`, `medicine after war`, `repairing what was broken`

# %% [markdown]
# ### Primary Characters
# Avendar, Halana

# %% [markdown]
# ### Lineage Thread
# - Halana — Last Sunspeaker (Light)

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Valor** → [01_VALOR/02_What_It_Cost](../../01_VALOR/02_What_It_Cost/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
