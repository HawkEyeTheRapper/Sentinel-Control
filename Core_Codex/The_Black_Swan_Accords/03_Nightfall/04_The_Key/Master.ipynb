# %% [markdown]
# # The Key
#
# **Series:** Nightfall (03_Nightfall)  \
# **Book ID:** `04_The_Key`  \
# **Sequence:** 4

# %% [markdown]
# ### Tags
# `ancient lineage`, `bloodline awakening`, `hidden inheritance`, `unlocking memory`, `Alexia’s descent`

# %% [markdown]
# ### Primary Characters
# Alexia, Brian_McCord

# %% [markdown]
# ### Lineage Thread
# - Alexia — Celestial Heir (Ascension)

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Valor** → [01_VALOR/03_How_We_Changed](../../01_VALOR/03_How_We_Changed/Master.ipynb)
# - **Unveiling** → [02_The_Unveiling/07_Sun_Moon_And_Stars](../../02_The_Unveiling/07_Sun_Moon_And_Stars/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
