# %% [markdown]
# # The Beginning
#
# **Series:** Nightfall (03_Nightfall)  \
# **Book ID:** `01_The_Beginning`  \
# **Sequence:** 1

# %% [markdown]
# ### Tags
# `setup`, `quiet war`, `shadow operations`, `convergence of arcs`, `prelude to endgame`

# %% [markdown]
# ### Primary Characters
# Brian_McCord, Harker, Fenningway

# %% [markdown]
# ### Lineage Thread
# - _(no direct lineage anchor in this volume)_

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Valor** → [01_VALOR/03_How_We_Changed](../../01_VALOR/03_How_We_Changed/Master.ipynb)
# - **Unveiling** → [02_The_Unveiling/01_First_Light](../../02_The_Unveiling/01_First_Light/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
