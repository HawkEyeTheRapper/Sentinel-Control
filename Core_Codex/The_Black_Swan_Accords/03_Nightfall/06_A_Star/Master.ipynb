# %% [markdown]
# # A Star
#
# **Series:** Nightfall (03_Nightfall)  \
# **Book ID:** `06_A_Star`  \
# **Sequence:** 6

# %% [markdown]
# ### Tags
# `celestial memory`, `heritage of the sun`, `Preori origins`, `Divine spark`, `rising power`

# %% [markdown]
# ### Primary Characters
# Alexia, Halana

# %% [markdown]
# ### Lineage Thread
# - Halana — Last Sunspeaker (Light)
# - Alexia — Celestial Heir (Ascension)

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Valor** → [01_VALOR/01_When_First_They_Came](../../01_VALOR/01_When_First_They_Came/Master.ipynb)
# - **Unveiling** → [02_The_Unveiling/01_First_Light](../../02_The_Unveiling/01_First_Light/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
