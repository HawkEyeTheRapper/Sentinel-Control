# %% [markdown]
# # Dawn
#
# **Series:** Nightfall (03_Nightfall)  \
# **Book ID:** `08_Dawn`  \
# **Sequence:** 8

# %% [markdown]
# ### Tags
# `end of shadow`, `integration`, `return of the starwalkers`, `rebirth`, `cycle complete`

# %% [markdown]
# ### Primary Characters
# Alexia, Brian_McCord, Halana

# %% [markdown]
# ### Lineage Thread
# - Halana — Last Sunspeaker (Light)
# - Alexia — Celestial Heir (Ascension)

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Valor** → [01_VALOR/03_How_We_Changed](../../01_VALOR/03_How_We_Changed/Master.ipynb)
# - **Unveiling** → [02_The_Unveiling/13_The_Last_Sunspeaker](../../02_The_Unveiling/13_The_Last_Sunspeaker/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
