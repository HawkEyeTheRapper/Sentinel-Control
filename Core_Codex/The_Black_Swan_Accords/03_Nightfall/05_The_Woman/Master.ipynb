# %% [markdown]
# # The Woman
#
# **Series:** Nightfall (03_Nightfall)  \
# **Book ID:** `05_The_Woman`  \
# **Sequence:** 5

# %% [markdown]
# ### Tags
# `identity`, `shadow confrontation`, `self-revelation`, `the fracture`, `becoming`

# %% [markdown]
# ### Primary Characters
# Alexia

# %% [markdown]
# ### Lineage Thread
# - Alexia — Celestial Heir (Ascension)

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Valor** → [01_VALOR/02_What_It_Cost](../../01_VALOR/02_What_It_Cost/Master.ipynb)
# - **Unveiling** → [02_The_Unveiling/06_If_Any_Hath_An_Ear](../../02_The_Unveiling/06_If_Any_Hath_An_Ear/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
