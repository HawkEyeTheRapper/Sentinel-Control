# %% [markdown]
# # Nightfall (03_Nightfall)
#
# The long shadow, the game behind the game, and the quiet war.

# %% [markdown]
# ### Themes
# `conspiracy`, `shadow work`, `endgame`

# %% [markdown]
# ### Books
# - **The Beginning** (`01_The_Beginning`) — [open](../01_The_Beginning/Master.ipynb)
# - **The Game** (`02_The_Game`) — [open](../02_The_Game/Master.ipynb)
# - **The Drifter** (`03_The_Drifter`) — [open](../03_The_Drifter/Master.ipynb)
# - **The Key** (`04_The_Key`) — [open](../04_The_Key/Master.ipynb)
# - **The Woman** (`05_The_Woman`) — [open](../05_The_Woman/Master.ipynb)
# - **A Star** (`06_A_Star`) — [open](../06_A_Star/Master.ipynb)
# - **A Tree** (`07_A_Tree`) — [open](../07_A_Tree/Master.ipynb)
# - **Dawn** (`08_Dawn`) — [open](../08_Dawn/Master.ipynb)
