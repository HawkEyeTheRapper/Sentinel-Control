# %% [markdown]
# # VALOR (01_VALOR)
#
# Front-line resistance and the cost of standing up.

# %% [markdown]
# ### Themes
# `sacrifice`, `courage`, `occupation`, `memory`

# %% [markdown]
# ### Books
# - **When First They Came** (`01_When_First_They_Came`) — [open](../01_When_First_They_Came/Master.ipynb)
# - **What It Cost** (`02_What_It_Cost`) — [open](../02_What_It_Cost/Master.ipynb)
# - **How We Changed** (`03_How_We_Changed`) — [open](../03_How_We_Changed/Master.ipynb)
