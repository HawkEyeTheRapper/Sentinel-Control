# %% [markdown]
# # How We Changed
#
# **Series:** VALOR (01_VALOR)  \
# **Book ID:** `03_How_We_Changed`  \
# **Sequence:** 3

# %% [markdown]
# ### Tags
# `transformation`, `myth-making`, `legacy of Selene`, `sentinel path`, `waiting for Those Who Return`, `world reshaped by absence`

# %% [markdown]
# ### Primary Characters
# Selene

# %% [markdown]
# ### Lineage Thread
# - Selene — Last Sentinel (Will)

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Unveiling** → [02_The_Unveiling/04_A_Time_For_Healing](../../02_The_Unveiling/04_A_Time_For_Healing/Master.ipynb)
# - **Nightfall** → [03_Nightfall/01_The_Beginning](../../03_Nightfall/01_The_Beginning/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
