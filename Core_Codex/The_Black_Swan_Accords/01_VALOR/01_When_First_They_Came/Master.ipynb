# %% [markdown]
# # When First They Came
#
# **Series:** VALOR (01_VALOR)  \
# **Book ID:** `01_When_First_They_Came`  \
# **Sequence:** 1

# %% [markdown]
# ### Tags
# `invasion`, `occupation`, `first resistance`, `loss of guardians`, `beginning of the long war`

# %% [markdown]
# ### Primary Characters
# Gareth, Selene, Diana_Swan

# %% [markdown]
# ### Lineage Thread
# - Selene — Last Sentinel (Will)

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Unveiling** → [02_The_Unveiling/01_First_Light](../../02_The_Unveiling/01_First_Light/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
