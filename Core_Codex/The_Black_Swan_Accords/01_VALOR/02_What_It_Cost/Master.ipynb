# %% [markdown]
# # What It Cost
#
# **Series:** VALOR (01_VALOR)  \
# **Book ID:** `02_What_It_Cost`  \
# **Sequence:** 2

# %% [markdown]
# ### Tags
# `grief`, `aftermath`, `the Valkyr’s stand`, `sacrifice`, `legend of the Last Sentinel`, `price of resistance`

# %% [markdown]
# ### Primary Characters
# Selene, Gareth

# %% [markdown]
# ### Lineage Thread
# - Selene — Last Sentinel (Will)

# %% [markdown]
# ### Navigation
# - [⬆ Back to Series Master](../00_Series_Master/Master.ipynb)
#
# **Linked Volumes Across Arcs:**
# - **Unveiling** → [02_The_Unveiling/02_Forgotten_Knowledge](../../02_The_Unveiling/02_Forgotten_Knowledge/Master.ipynb)

# %% [markdown]
# ---
# ### Working Notes
#
# Use this space for:
# - scene lists
# - structural beats
# - questions for future revision
# - cross-references to VALOR / The Unveiling / Nightfall
#
# You can always regenerate this notebook from `FormingTheAccords.ipynb` if the structure changes.
